# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl (38.8 MB)
#      -------------------------------------- 38.8/38.8 MB 414.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in c:\users\devna\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.82
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
print(cv2.__version__)
from matplotlib import pyplot as plt
# Out:
# 4.10.0

# %%
image = cv2.imread(r'C:\Users\devna\Documents\Computer Vision\Image Processing\lion.jpg')
image_rgb= cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
